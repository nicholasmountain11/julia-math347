# %%
A = [-1 1;0 0;1 1;2 4];
A'
# Out:
# 2×4 adjoint(::Matrix{Int64}) with eltype Int64:
#  -1  0  1  2
#   1  0  1  4

# %%
D = [-1 -3;0 0;1 5;2 1];
x = D[:,1];
y = D[:,2];
# Out:
# 4-element Vector{Int64}:
#  -3
#   0
#   5
#   1

# %%
using Plots

# %%
A = [x x.^2];
c = inv(A'*A)*(A'*y);
p = A*c;

# %%
scatter(x,y)
plot!(x,p)
